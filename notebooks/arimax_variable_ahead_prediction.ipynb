# %%
import warnings
import pandas as pd
windows = [3,7,14,21,30,60]
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
warnings.filterwarnings('ignore')

# %%
from python_scripts.sarima_helper import train_test_split_continual, predict_with_windows

lag_features = ["High", "Low", "Volume", "Open", "reddit_average_posts_48h",
                "reddit_average_comments_48h", "reddit_subscribers", "reddit_accounts_active_48h",
                'shiba inu coin_unscaled', 'shiba inu coin_monthly', 'scale', 'shiba inu coin']

#Predikcija za skup 70:30
for window in windows:
    df_shiba = pd.read_csv(f'../shiba_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_shiba.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_shiba, 0.3)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no shiba inu coin_unscaled_mean_lag3 in data frame
# There is no shiba inu coin_monthly_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-8160.948, Time=1.85 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-8160.716, Time=1.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-8166.281, Time=1.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-8161.705, Time=1.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7040.226, Time=0.88 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-8164.846, Time=1.25 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-8164.788, Time=1.23 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-8162.861, Time=1.33 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-8168.279, Time=0.90 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-8166.842, Time=1.09 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-8166.787, Time=1.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-8163.696, Time=0.99 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-8164.859, Time=1.18 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 15.035 seconds
# MAPE for 3 day lag prediction is 47.29129512633515
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no shiba inu coin_unscaled_mean_lag7 in data frame
# There is no shiba inu coin_monthly_mean_lag7 in data frame
# There is no shiba inu coin_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-8164.412, Time=1.39 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-8153.700, Time=0.74 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-8170.346, Time=0.87 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-8164.324, Time=0.92 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6867.867, Time=0.65 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-8168.402, Time=1.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-8168.402, Time=1.04 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-8166.493, Time=1.13 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-8172.347, Time=0.79 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-8170.403, Time=0.95 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-8170.403, Time=0.92 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-8166.324, Time=0.84 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-8168.496, Time=1.03 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 12.292 seconds
# MAPE for 7 day lag prediction is 64.90996221437787
# There is no High_mean_lag14 in data frame
# There is no Low_mean_lag14 in data frame
# There is no Volume_mean_lag14 in data frame
# There is no reddit_average_comments_48h_mean_lag14 in data frame
# There is no reddit_accounts_active_48h_mean_lag14 in data frame
# There is no shiba inu coin_unscaled_mean_lag14 in data frame
# There is no shiba inu coin_monthly_mean_lag14 in data frame
# There is no shiba inu coin_mean_lag14 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-8168.457, Time=1.36 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-8160.553, Time=0.62 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-8174.337, Time=0.75 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-8167.191, Time=0.76 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6910.458, Time=0.51 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-8172.370, Time=0.84 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-8172.365, Time=0.85 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-8154.550, Time=0.94 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-8176.337, Time=0.58 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-8174.370, Time=0.74 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-8174.365, Time=0.74 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-8169.191, Time=0.64 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-8156.550, Time=0.83 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 10.169 seconds
# MAPE for 14 day lag prediction is 83.47305475230857
# There is no High_mean_lag21 in data frame
# There is no Low_mean_lag21 in data frame
# There is no Volume_mean_lag21 in data frame
# There is no reddit_average_comments_48h_mean_lag21 in data frame
# There is no reddit_accounts_active_48h_mean_lag21 in data frame
# There is no shiba inu coin_unscaled_mean_lag21 in data frame
# There is no shiba inu coin_monthly_mean_lag21 in data frame
# There is no shiba inu coin_mean_lag21 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-8170.457, Time=1.20 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-8172.328, Time=0.60 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-8176.385, Time=0.68 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-8174.618, Time=0.74 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7129.700, Time=0.49 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-8174.443, Time=0.84 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-8174.438, Time=0.85 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-8172.449, Time=0.96 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-8178.383, Time=0.58 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-8176.441, Time=0.74 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-8176.436, Time=0.75 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-8176.611, Time=0.66 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-8174.446, Time=0.85 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 9.975 seconds
# MAPE for 21 day lag prediction is 89.99292749292586
# There is no High_mean_lag30 in data frame
# There is no Low_mean_lag30 in data frame
# There is no Volume_mean_lag30 in data frame
# There is no reddit_average_comments_48h_mean_lag30 in data frame
# There is no reddit_accounts_active_48h_mean_lag30 in data frame
# There is no shiba inu coin_unscaled_mean_lag30 in data frame
# There is no shiba inu coin_monthly_mean_lag30 in data frame
# There is no scale_mean_lag30 in data frame
# There is no shiba inu coin_mean_lag30 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-8131.179, Time=1.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-8138.714, Time=0.57 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-8137.025, Time=0.71 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-8137.018, Time=0.79 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7336.319, Time=0.46 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-8135.025, Time=0.89 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 4.564 seconds
# MAPE for 30 day lag prediction is 55.47502281124055
# There is no High_mean_lag60 in data frame
# There is no Low_mean_lag60 in data frame
# There is no Volume_mean_lag60 in data frame
# There is no Open_mean_lag60 in data frame
# There is no reddit_average_posts_48h_mean_lag60 in data frame
# There is no reddit_average_comments_48h_mean_lag60 in data frame
# There is no reddit_accounts_active_48h_mean_lag60 in data frame
# There is no shiba inu coin_unscaled_mean_lag60 in data frame
# There is no shiba inu coin_monthly_mean_lag60 in data frame
# There is no scale_mean_lag60 in data frame
# There is no shiba inu coin_mean_lag60 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-8135.154, Time=0.92 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-8142.712, Time=0.40 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-8141.015, Time=0.48 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-8141.008, Time=0.57 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7340.229, Time=0.28 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-8139.015, Time=0.69 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 3.349 seconds
# MAPE for 60 day lag prediction is 55.74515616442325

# %%
for window in windows:
    df_shiba = pd.read_csv(f'../shiba_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_shiba.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_shiba, 0.2)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no shiba inu coin_unscaled_mean_lag3 in data frame
# There is no shiba inu coin_monthly_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-9322.626, Time=2.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9320.395, Time=1.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-9328.034, Time=1.12 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9325.805, Time=1.22 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7928.544, Time=0.89 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-9326.527, Time=1.35 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-9326.644, Time=1.33 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-9324.651, Time=1.45 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-9330.034, Time=1.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-9328.527, Time=1.20 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-9328.645, Time=1.21 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-9327.801, Time=1.10 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-9326.652, Time=1.31 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 16.400 seconds
# MAPE for 3 day lag prediction is 57.41668742005498
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no shiba inu coin_unscaled_mean_lag7 in data frame
# There is no shiba inu coin_monthly_mean_lag7 in data frame
# There is no shiba inu coin_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-9320.650, Time=1.52 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9296.488, Time=0.82 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-9326.478, Time=0.94 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9319.497, Time=1.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7598.596, Time=0.74 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-9324.492, Time=1.17 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-9324.495, Time=1.15 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-9322.548, Time=1.25 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-9328.480, Time=0.83 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-9326.494, Time=0.99 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-9326.498, Time=1.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-9321.497, Time=0.91 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-9324.596, Time=1.13 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 13.537 seconds
# MAPE for 7 day lag prediction is 62.44872251548402
# There is no High_mean_lag14 in data frame
# There is no Low_mean_lag14 in data frame
# There is no Volume_mean_lag14 in data frame
# There is no reddit_average_comments_48h_mean_lag14 in data frame
# There is no reddit_accounts_active_48h_mean_lag14 in data frame
# There is no shiba inu coin_unscaled_mean_lag14 in data frame
# There is no shiba inu coin_monthly_mean_lag14 in data frame
# There is no shiba inu coin_mean_lag14 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-9328.987, Time=1.32 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9278.984, Time=0.67 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-9335.273, Time=0.76 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9312.605, Time=0.85 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7451.082, Time=0.57 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-9333.270, Time=0.92 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-9333.271, Time=0.95 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-9272.980, Time=1.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-9337.271, Time=0.66 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-9335.267, Time=0.84 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-9335.269, Time=0.82 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-9314.602, Time=0.72 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-9274.983, Time=0.91 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 11.020 seconds
# MAPE for 14 day lag prediction is 88.14090392468144
# There is no High_mean_lag21 in data frame
# There is no Low_mean_lag21 in data frame
# There is no Volume_mean_lag21 in data frame
# There is no reddit_average_comments_48h_mean_lag21 in data frame
# There is no reddit_accounts_active_48h_mean_lag21 in data frame
# There is no shiba inu coin_unscaled_mean_lag21 in data frame
# There is no shiba inu coin_monthly_mean_lag21 in data frame
# There is no shiba inu coin_mean_lag21 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-9282.643, Time=1.36 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9290.694, Time=0.67 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-9335.203, Time=0.74 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9319.054, Time=0.85 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7527.003, Time=0.56 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-9333.207, Time=0.93 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-9333.207, Time=0.95 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-9331.202, Time=1.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-9337.203, Time=0.68 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-9335.208, Time=0.81 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-9335.208, Time=0.81 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-9321.094, Time=0.72 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-9333.206, Time=0.91 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 11.053 seconds
# MAPE for 21 day lag prediction is 102.43430192645503
# There is no High_mean_lag30 in data frame
# There is no Low_mean_lag30 in data frame
# There is no Volume_mean_lag30 in data frame
# There is no reddit_average_comments_48h_mean_lag30 in data frame
# There is no reddit_accounts_active_48h_mean_lag30 in data frame
# There is no shiba inu coin_unscaled_mean_lag30 in data frame
# There is no shiba inu coin_monthly_mean_lag30 in data frame
# There is no scale_mean_lag30 in data frame
# There is no shiba inu coin_mean_lag30 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-9331.138, Time=1.29 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9274.532, Time=0.62 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-9337.125, Time=0.71 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9309.385, Time=0.73 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7415.114, Time=0.47 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-9335.125, Time=0.84 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-9335.126, Time=0.85 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-9268.428, Time=0.98 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-9339.111, Time=0.56 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-9337.111, Time=0.73 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-9337.112, Time=0.73 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-9310.686, Time=0.63 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-9270.336, Time=0.89 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 10.050 seconds
# MAPE for 30 day lag prediction is 93.66739654911567
# There is no High_mean_lag60 in data frame
# There is no Low_mean_lag60 in data frame
# There is no Volume_mean_lag60 in data frame
# There is no Open_mean_lag60 in data frame
# There is no reddit_average_posts_48h_mean_lag60 in data frame
# There is no reddit_average_comments_48h_mean_lag60 in data frame
# There is no reddit_accounts_active_48h_mean_lag60 in data frame
# There is no shiba inu coin_unscaled_mean_lag60 in data frame
# There is no shiba inu coin_monthly_mean_lag60 in data frame
# There is no scale_mean_lag60 in data frame
# There is no shiba inu coin_mean_lag60 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-9298.063, Time=1.01 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-9305.564, Time=0.43 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-9303.918, Time=0.52 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-9303.896, Time=0.65 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8275.019, Time=0.34 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-9301.912, Time=0.74 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 3.705 seconds
# MAPE for 60 day lag prediction is 28.61125953537975

# %%
for window in windows:
    df_shiba = pd.read_csv(f'../shiba_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_shiba.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_shiba, 0.1)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no shiba inu coin_unscaled_mean_lag3 in data frame
# There is no shiba inu coin_monthly_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-10491.598, Time=1.93 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-10478.240, Time=1.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-10497.463, Time=1.23 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-10494.303, Time=1.31 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-8551.775, Time=1.00 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-10495.668, Time=1.45 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-10495.650, Time=1.50 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-10493.790, Time=1.60 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-10499.464, Time=1.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-10497.670, Time=1.31 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-10497.655, Time=1.31 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-10496.304, Time=1.22 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-10495.800, Time=1.47 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 17.567 seconds
# MAPE for 3 day lag prediction is 7.155959870508613
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no shiba inu coin_unscaled_mean_lag7 in data frame
# There is no shiba inu coin_monthly_mean_lag7 in data frame
# There is no shiba inu coin_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-10461.032, Time=1.69 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-10368.635, Time=0.89 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-10463.299, Time=1.01 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-10428.054, Time=1.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7987.721, Time=0.79 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-10462.745, Time=1.21 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-10462.413, Time=1.25 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-10460.539, Time=1.36 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-10465.292, Time=0.90 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-10464.742, Time=1.10 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-10464.413, Time=1.11 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-10430.034, Time=1.00 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-10462.538, Time=1.23 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 14.713 seconds
# MAPE for 7 day lag prediction is 14.896573416805174
# There is no High_mean_lag14 in data frame
# There is no Low_mean_lag14 in data frame
# There is no Volume_mean_lag14 in data frame
# There is no reddit_average_comments_48h_mean_lag14 in data frame
# There is no reddit_accounts_active_48h_mean_lag14 in data frame
# There is no shiba inu coin_unscaled_mean_lag14 in data frame
# There is no shiba inu coin_monthly_mean_lag14 in data frame
# There is no shiba inu coin_mean_lag14 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-10485.102, Time=1.42 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-10221.857, Time=0.73 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-10489.833, Time=0.85 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-10385.742, Time=0.93 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7671.018, Time=0.62 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-10488.243, Time=1.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-10488.149, Time=1.01 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-10215.554, Time=1.14 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-10491.832, Time=0.71 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-10490.244, Time=0.88 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-10490.151, Time=0.90 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-10387.655, Time=0.77 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-10217.553, Time=1.01 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 12.001 seconds
# MAPE for 14 day lag prediction is 19.230814312482913
# There is no High_mean_lag21 in data frame
# There is no Low_mean_lag21 in data frame
# There is no Volume_mean_lag21 in data frame
# There is no reddit_average_comments_48h_mean_lag21 in data frame
# There is no reddit_accounts_active_48h_mean_lag21 in data frame
# There is no shiba inu coin_unscaled_mean_lag21 in data frame
# There is no shiba inu coin_monthly_mean_lag21 in data frame
# There is no shiba inu coin_mean_lag21 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-10485.516, Time=1.40 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-10136.951, Time=0.72 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-10490.145, Time=0.82 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-10354.217, Time=0.91 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-7552.650, Time=0.63 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-10489.774, Time=1.00 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-10489.413, Time=1.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-10488.661, Time=1.18 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-10492.141, Time=0.71 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-10491.774, Time=0.89 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-10491.414, Time=0.92 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-10355.995, Time=0.79 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-10490.661, Time=1.03 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 12.054 seconds
# MAPE for 21 day lag prediction is 17.156723948500733
# There is no High_mean_lag30 in data frame
# There is no Low_mean_lag30 in data frame
# There is no Volume_mean_lag30 in data frame
# There is no reddit_average_comments_48h_mean_lag30 in data frame
# There is no reddit_accounts_active_48h_mean_lag30 in data frame
# There is no shiba inu coin_unscaled_mean_lag30 in data frame
# There is no shiba inu coin_monthly_mean_lag30 in data frame
# There is no scale_mean_lag30 in data frame
# There is no shiba inu coin_mean_lag30 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-10459.428, Time=1.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-10466.044, Time=0.73 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-10465.193, Time=0.80 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-10465.017, Time=0.93 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8780.375, Time=0.55 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-10463.418, Time=1.09 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 5.457 seconds
# MAPE for 30 day lag prediction is 29.977635676497517
# There is no High_mean_lag60 in data frame
# There is no Low_mean_lag60 in data frame
# There is no Volume_mean_lag60 in data frame
# There is no Open_mean_lag60 in data frame
# There is no reddit_average_posts_48h_mean_lag60 in data frame
# There is no reddit_average_comments_48h_mean_lag60 in data frame
# There is no reddit_accounts_active_48h_mean_lag60 in data frame
# There is no shiba inu coin_unscaled_mean_lag60 in data frame
# There is no shiba inu coin_monthly_mean_lag60 in data frame
# There is no scale_mean_lag60 in data frame
# There is no shiba inu coin_mean_lag60 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-10445.746, Time=1.09 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-10469.902, Time=0.46 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-10468.978, Time=0.58 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-10468.820, Time=0.70 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8782.257, Time=0.59 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-10467.200, Time=1.11 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 4.557 seconds
# MAPE for 60 day lag prediction is 28.90994871250267

# %%
lag_features = ["High", "Low", "Volume", "Open", "twitter_followers", "reddit_average_posts_48h",
                "reddit_average_comments_48h", "reddit_subscribers", "reddit_accounts_active_48h", 'idena_unscaled',
                'idena_monthly', 'scale', 'idena']
windows =[3,7]
#Predikcija za skup 70:30
for window in windows:
    df_idena = pd.read_csv(f'../idena_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_idena.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_idena, 0.3)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no Volume_mean_lag3 in data frame
# There is no twitter_followers_mean_lag3 in data frame
# There is no reddit_average_posts_48h_mean_lag3 in data frame
# There is no reddit_average_comments_48h_mean_lag3 in data frame
# There is no reddit_subscribers_mean_lag3 in data frame
# There is no reddit_accounts_active_48h_mean_lag3 in data frame
# There is no idena_unscaled_mean_lag3 in data frame
# There is no idena_monthly_mean_lag3 in data frame
# There is no scale_mean_lag3 in data frame
# There is no idena_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-2242.028, Time=2.43 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-1763.402, Time=0.37 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2265.795, Time=0.97 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2022.222, Time=0.77 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-1743.466, Time=0.30 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-2264.084, Time=1.52 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2264.032, Time=1.61 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-2264.855, Time=2.18 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=1.07 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 11.240 seconds
# MAPE for 3 day lag prediction is 17.72455469116001
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no twitter_followers_mean_lag7 in data frame
# There is no reddit_average_posts_48h_mean_lag7 in data frame
# There is no reddit_average_comments_48h_mean_lag7 in data frame
# There is no reddit_subscribers_mean_lag7 in data frame
# There is no reddit_accounts_active_48h_mean_lag7 in data frame
# There is no idena_unscaled_mean_lag7 in data frame
# There is no idena_monthly_mean_lag7 in data frame
# There is no scale_mean_lag7 in data frame
# There is no idena_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-2177.423, Time=2.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-1530.941, Time=0.26 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2261.361, Time=1.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-1818.781, Time=1.07 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-1488.990, Time=0.21 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-2260.140, Time=1.37 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2259.593, Time=1.57 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-2263.249, Time=2.36 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-2261.516, Time=2.12 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-2260.971, Time=1.99 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-2255.197, Time=2.29 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-2256.507, Time=3.71 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-2258.390, Time=1.96 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0] intercept
# Total fit time: 22.086 seconds
# MAPE for 7 day lag prediction is 19.934006352795

# %%
#Predikcija za skup 80:20
for window in windows:
    df_idena = pd.read_csv(f'../idena_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_idena.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_idena, 0.2)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no Volume_mean_lag3 in data frame
# There is no twitter_followers_mean_lag3 in data frame
# There is no reddit_average_posts_48h_mean_lag3 in data frame
# There is no reddit_average_comments_48h_mean_lag3 in data frame
# There is no reddit_subscribers_mean_lag3 in data frame
# There is no reddit_accounts_active_48h_mean_lag3 in data frame
# There is no idena_unscaled_mean_lag3 in data frame
# There is no idena_monthly_mean_lag3 in data frame
# There is no scale_mean_lag3 in data frame
# There is no idena_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-2597.032, Time=2.53 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-2059.659, Time=0.42 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2631.779, Time=1.21 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2351.793, Time=0.51 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-2037.259, Time=0.35 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-2630.308, Time=2.11 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2629.571, Time=1.60 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-2631.587, Time=2.38 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.97 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 12.107 seconds
# MAPE for 3 day lag prediction is 17.3747381768409
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no twitter_followers_mean_lag7 in data frame
# There is no reddit_average_posts_48h_mean_lag7 in data frame
# There is no reddit_average_comments_48h_mean_lag7 in data frame
# There is no reddit_subscribers_mean_lag7 in data frame
# There is no reddit_accounts_active_48h_mean_lag7 in data frame
# There is no idena_unscaled_mean_lag7 in data frame
# There is no idena_monthly_mean_lag7 in data frame
# There is no scale_mean_lag7 in data frame
# There is no idena_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-2571.266, Time=2.43 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-1795.986, Time=0.53 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2627.511, Time=1.28 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2124.057, Time=1.01 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-1748.502, Time=0.40 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-2626.621, Time=1.72 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2626.407, Time=1.69 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-2630.243, Time=2.48 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-2625.570, Time=2.45 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-2628.251, Time=2.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-2628.927, Time=2.37 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-2623.508, Time=3.78 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-2624.607, Time=1.94 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0] intercept
# Total fit time: 24.243 seconds
# MAPE for 7 day lag prediction is 18.84528040299768

# %%
#Predikcija za skup 90:10
for window in windows:
    df_idena = pd.read_csv(f'../idena_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_idena.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_idena, 0.1)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no Volume_mean_lag3 in data frame
# There is no twitter_followers_mean_lag3 in data frame
# There is no reddit_average_posts_48h_mean_lag3 in data frame
# There is no reddit_average_comments_48h_mean_lag3 in data frame
# There is no reddit_subscribers_mean_lag3 in data frame
# There is no reddit_accounts_active_48h_mean_lag3 in data frame
# There is no idena_unscaled_mean_lag3 in data frame
# There is no idena_monthly_mean_lag3 in data frame
# There is no scale_mean_lag3 in data frame
# There is no idena_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-2947.319, Time=2.60 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-2356.542, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-3002.583, Time=1.27 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2685.147, Time=0.89 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-2328.876, Time=0.45 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-3001.298, Time=2.15 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2986.464, Time=1.79 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-3002.593, Time=2.36 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-2996.672, Time=2.95 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-3002.915, Time=2.41 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-2739.067, Time=1.92 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-2993.183, Time=2.81 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=-2998.468, Time=2.69 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-2995.948, Time=3.39 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-2994.030, Time=2.70 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0] intercept
# Total fit time: 30.646 seconds
# MAPE for 3 day lag prediction is 23.504648206944285
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no twitter_followers_mean_lag7 in data frame
# There is no reddit_average_posts_48h_mean_lag7 in data frame
# There is no reddit_average_comments_48h_mean_lag7 in data frame
# There is no reddit_subscribers_mean_lag7 in data frame
# There is no reddit_accounts_active_48h_mean_lag7 in data frame
# There is no idena_unscaled_mean_lag7 in data frame
# There is no idena_monthly_mean_lag7 in data frame
# There is no scale_mean_lag7 in data frame
# There is no idena_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-2899.541, Time=2.54 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-2053.122, Time=0.91 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-2997.700, Time=1.30 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-2427.021, Time=1.12 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-1993.874, Time=0.24 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-2997.017, Time=1.75 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-2996.786, Time=2.26 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-2999.561, Time=2.50 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-2998.860, Time=3.62 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-2975.499, Time=2.84 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-2998.947, Time=2.41 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-2989.780, Time=3.86 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-2994.317, Time=2.64 sec
#
# Best model:  ARIMA(2,0,1)(0,0,0)[0] intercept
# Total fit time: 28.022 seconds
# MAPE for 7 day lag prediction is 19.47855277668692

# %%
lag_features = ["High", "Low", "Volume", "Open", "twitter_followers", "reddit_average_posts_48h",
                "reddit_average_comments_48h", "reddit_subscribers", "reddit_accounts_active_48h", "forks", "stars",
                "subscribers", "total_issues", "closed_issues", "pull_requests_merged", "pull_request_contributors",
                "commit_count_4_weeks", "dogecoin_monthly", "dogecoin"]
windows = [3,7,14,21,30,60]
#Predikcija za skup 70:30
for window in windows:
    df_doge = pd.read_csv(f'../doge_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_doge.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_doge, 0.3)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no Volume_mean_lag3 in data frame
# There is no twitter_followers_mean_lag3 in data frame
# There is no reddit_average_comments_48h_mean_lag3 in data frame
# There is no reddit_subscribers_mean_lag3 in data frame
# There is no reddit_accounts_active_48h_mean_lag3 in data frame
# There is no forks_mean_lag3 in data frame
# There is no stars_mean_lag3 in data frame
# There is no subscribers_mean_lag3 in data frame
# There is no total_issues_mean_lag3 in data frame
# There is no pull_requests_merged_mean_lag3 in data frame
# There is no commit_count_4_weeks_mean_lag3 in data frame
# There is no dogecoin_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-6724.401, Time=7.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-11601.918, Time=3.82 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-13607.207, Time=3.66 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-12187.441, Time=4.50 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-5111.470, Time=29.83 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-13606.820, Time=4.41 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-13594.189, Time=4.68 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-13591.688, Time=5.08 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-13608.607, Time=3.23 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-13609.253, Time=4.58 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=-13604.033, Time=6.26 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-13594.360, Time=5.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-13596.789, Time=4.49 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-13592.239, Time=6.36 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 93.096 seconds
# MAPE for 3 day lag prediction is 74.63303223792059
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no twitter_followers_mean_lag7 in data frame
# There is no reddit_average_comments_48h_mean_lag7 in data frame
# There is no reddit_subscribers_mean_lag7 in data frame
# There is no reddit_accounts_active_48h_mean_lag7 in data frame
# There is no forks_mean_lag7 in data frame
# There is no stars_mean_lag7 in data frame
# There is no subscribers_mean_lag7 in data frame
# There is no total_issues_mean_lag7 in data frame
# There is no pull_requests_merged_mean_lag7 in data frame
# There is no commit_count_4_weeks_mean_lag7 in data frame
# There is no dogecoin_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-13608.171, Time=6.42 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-11508.047, Time=4.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-13610.454, Time=2.47 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-11903.323, Time=4.57 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-5017.581, Time=30.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-13610.857, Time=4.88 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-13611.110, Time=6.26 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=-13610.507, Time=7.42 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-13606.802, Time=7.01 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-13568.019, Time=5.23 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=-13609.363, Time=7.60 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=-13613.095, Time=5.39 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-13612.851, Time=4.19 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=-13612.478, Time=67.66 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-13608.794, Time=6.01 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-13580.452, Time=2.11 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=-13611.322, Time=6.62 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[0]
# Total fit time: 177.926 seconds
# MAPE for 7 day lag prediction is 79.49264867760832
# There is no High_mean_lag14 in data frame
# There is no Low_mean_lag14 in data frame
# There is no Volume_mean_lag14 in data frame
# There is no twitter_followers_mean_lag14 in data frame
# There is no reddit_average_comments_48h_mean_lag14 in data frame
# There is no reddit_subscribers_mean_lag14 in data frame
# There is no reddit_accounts_active_48h_mean_lag14 in data frame
# There is no forks_mean_lag14 in data frame
# There is no stars_mean_lag14 in data frame
# There is no subscribers_mean_lag14 in data frame
# There is no total_issues_mean_lag14 in data frame
# There is no pull_requests_merged_mean_lag14 in data frame
# There is no commit_count_4_weeks_mean_lag14 in data frame
# There is no dogecoin_mean_lag14 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-14402.872, Time=2.97 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-14402.977, Time=1.69 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-14422.457, Time=1.89 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-14422.598, Time=2.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-14378.242, Time=4.60 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-14420.635, Time=2.44 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-14420.062, Time=2.52 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-14418.593, Time=2.80 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-14424.596, Time=1.97 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-14422.633, Time=2.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-14422.059, Time=2.20 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-14424.455, Time=1.66 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-14420.591, Time=2.48 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 31.580 seconds
# MAPE for 14 day lag prediction is 85.83785968208993
# There is no High_mean_lag21 in data frame
# There is no Low_mean_lag21 in data frame
# There is no Volume_mean_lag21 in data frame
# There is no twitter_followers_mean_lag21 in data frame
# There is no reddit_average_comments_48h_mean_lag21 in data frame
# There is no reddit_subscribers_mean_lag21 in data frame
# There is no reddit_accounts_active_48h_mean_lag21 in data frame
# There is no forks_mean_lag21 in data frame
# There is no stars_mean_lag21 in data frame
# There is no subscribers_mean_lag21 in data frame
# There is no total_issues_mean_lag21 in data frame
# There is no pull_requests_merged_mean_lag21 in data frame
# There is no commit_count_4_weeks_mean_lag21 in data frame
# There is no dogecoin_mean_lag21 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-14410.471, Time=7.03 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-14408.473, Time=1.71 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-14427.724, Time=4.65 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-14427.914, Time=5.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-14330.829, Time=5.57 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-14425.931, Time=5.74 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-14425.303, Time=5.81 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-14425.059, Time=6.70 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-14429.889, Time=4.49 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-14427.907, Time=5.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-14427.279, Time=5.16 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-14429.701, Time=4.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-14427.044, Time=5.96 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 67.191 seconds
# MAPE for 21 day lag prediction is 84.10246450668102
# There is no High_mean_lag30 in data frame
# There is no Low_mean_lag30 in data frame
# There is no Volume_mean_lag30 in data frame
# There is no twitter_followers_mean_lag30 in data frame
# There is no reddit_average_comments_48h_mean_lag30 in data frame
# There is no reddit_subscribers_mean_lag30 in data frame
# There is no reddit_accounts_active_48h_mean_lag30 in data frame
# There is no forks_mean_lag30 in data frame
# There is no stars_mean_lag30 in data frame
# There is no subscribers_mean_lag30 in data frame
# There is no total_issues_mean_lag30 in data frame
# There is no pull_requests_merged_mean_lag30 in data frame
# There is no commit_count_4_weeks_mean_lag30 in data frame
# There is no dogecoin_monthly_mean_lag30 in data frame
# There is no dogecoin_mean_lag30 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-14404.844, Time=2.71 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-14397.734, Time=1.49 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-14416.705, Time=1.70 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-14417.045, Time=1.94 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-14394.041, Time=4.67 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-14415.019, Time=2.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-14414.302, Time=2.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-14417.792, Time=2.52 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-14413.142, Time=3.19 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-14413.843, Time=2.88 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-14391.559, Time=2.45 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-14410.590, Time=3.46 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-14419.787, Time=2.33 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-14416.292, Time=2.34 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-14417.010, Time=2.05 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-14406.840, Time=2.49 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-14415.134, Time=2.82 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-14419.036, Time=1.76 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=-14415.835, Time=2.60 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-14393.546, Time=2.23 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-14412.581, Time=3.12 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 53.227 seconds
# MAPE for 30 day lag prediction is 85.38812875518921
# There is no High_mean_lag60 in data frame
# There is no Low_mean_lag60 in data frame
# There is no Volume_mean_lag60 in data frame
# There is no twitter_followers_mean_lag60 in data frame
# There is no reddit_average_comments_48h_mean_lag60 in data frame
# There is no reddit_subscribers_mean_lag60 in data frame
# There is no reddit_accounts_active_48h_mean_lag60 in data frame
# There is no forks_mean_lag60 in data frame
# There is no stars_mean_lag60 in data frame
# There is no subscribers_mean_lag60 in data frame
# There is no total_issues_mean_lag60 in data frame
# There is no closed_issues_mean_lag60 in data frame
# There is no pull_requests_merged_mean_lag60 in data frame
# There is no commit_count_4_weeks_mean_lag60 in data frame
# There is no dogecoin_monthly_mean_lag60 in data frame
# There is no dogecoin_mean_lag60 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-14430.705, Time=2.83 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-14439.217, Time=3.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-14462.935, Time=2.60 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-14461.107, Time=4.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-14441.106, Time=3.48 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-14461.644, Time=4.72 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-14461.379, Time=4.54 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=9.17 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-14464.867, Time=1.12 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=-14463.581, Time=2.85 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-14463.313, Time=4.09 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-14463.036, Time=3.62 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=7.47 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 53.664 seconds
# MAPE for 60 day lag prediction is 82.56774698178988

# %%
#Predikcija za skup 80:20
for window in windows:
    df_doge = pd.read_csv(f'../doge_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_doge.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_doge, 0.2)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no Volume_mean_lag3 in data frame
# There is no twitter_followers_mean_lag3 in data frame
# There is no reddit_average_comments_48h_mean_lag3 in data frame
# There is no reddit_subscribers_mean_lag3 in data frame
# There is no reddit_accounts_active_48h_mean_lag3 in data frame
# There is no forks_mean_lag3 in data frame
# There is no stars_mean_lag3 in data frame
# There is no subscribers_mean_lag3 in data frame
# There is no total_issues_mean_lag3 in data frame
# There is no pull_requests_merged_mean_lag3 in data frame
# There is no commit_count_4_weeks_mean_lag3 in data frame
# There is no dogecoin_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-8904.324, Time=9.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-10589.825, Time=1.72 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-11402.245, Time=4.18 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-11176.500, Time=4.75 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6157.025, Time=12.27 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-11372.538, Time=5.06 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-11236.569, Time=4.91 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-11224.659, Time=5.38 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-11404.362, Time=3.90 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-11375.383, Time=5.09 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-11239.912, Time=5.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-11179.527, Time=4.26 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-11227.980, Time=5.37 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 70.948 seconds
# MAPE for 3 day lag prediction is 20.728176104380562
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no twitter_followers_mean_lag7 in data frame
# There is no reddit_average_comments_48h_mean_lag7 in data frame
# There is no reddit_subscribers_mean_lag7 in data frame
# There is no reddit_accounts_active_48h_mean_lag7 in data frame
# There is no forks_mean_lag7 in data frame
# There is no stars_mean_lag7 in data frame
# There is no subscribers_mean_lag7 in data frame
# There is no total_issues_mean_lag7 in data frame
# There is no pull_requests_merged_mean_lag7 in data frame
# There is no commit_count_4_weeks_mean_lag7 in data frame
# There is no dogecoin_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-11425.354, Time=6.60 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9890.672, Time=1.92 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-11363.298, Time=4.55 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-10887.807, Time=4.88 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-9234.231, Time=12.95 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-11413.874, Time=7.29 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-8090.773, Time=5.95 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-11396.700, Time=8.62 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-11452.077, Time=7.54 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-11443.487, Time=6.86 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-11411.612, Time=8.29 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=-11460.126, Time=9.24 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=-11446.970, Time=8.58 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=-11341.332, Time=10.13 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=-11377.085, Time=9.54 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=-11351.392, Time=99.30 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=-11346.092, Time=10.37 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=-11462.029, Time=8.44 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=-11448.840, Time=7.74 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=-11454.465, Time=7.09 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=-11343.733, Time=9.03 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=-11378.661, Time=8.72 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=-11445.519, Time=6.90 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=-11352.890, Time=8.93 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-11413.973, Time=8.03 sec
#  ARIMA(3,0,5)(0,0,0)[0]             : AIC=-11347.789, Time=9.42 sec
#
# Best model:  ARIMA(2,0,4)(0,0,0)[0]
# Total fit time: 296.935 seconds
# MAPE for 7 day lag prediction is 36.83636288089093
# There is no High_mean_lag14 in data frame
# There is no Low_mean_lag14 in data frame
# There is no Volume_mean_lag14 in data frame
# There is no twitter_followers_mean_lag14 in data frame
# There is no reddit_average_comments_48h_mean_lag14 in data frame
# There is no reddit_subscribers_mean_lag14 in data frame
# There is no reddit_accounts_active_48h_mean_lag14 in data frame
# There is no forks_mean_lag14 in data frame
# There is no stars_mean_lag14 in data frame
# There is no subscribers_mean_lag14 in data frame
# There is no total_issues_mean_lag14 in data frame
# There is no pull_requests_merged_mean_lag14 in data frame
# There is no commit_count_4_weeks_mean_lag14 in data frame
# There is no dogecoin_mean_lag14 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-4818.489, Time=7.67 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-9409.847, Time=1.77 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-11707.675, Time=4.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-9750.433, Time=48.83 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-8965.029, Time=9.89 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-11705.495, Time=4.79 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-11705.255, Time=4.82 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-4916.690, Time=6.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-11709.675, Time=3.66 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-11707.496, Time=4.43 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-11707.252, Time=4.44 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=-9753.392, Time=3.02 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-4921.023, Time=2.34 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0]
# Total fit time: 105.757 seconds
# MAPE for 14 day lag prediction is 61.35874004470262
# There is no High_mean_lag21 in data frame
# There is no Low_mean_lag21 in data frame
# There is no Volume_mean_lag21 in data frame
# There is no twitter_followers_mean_lag21 in data frame
# There is no reddit_average_comments_48h_mean_lag21 in data frame
# There is no reddit_subscribers_mean_lag21 in data frame
# There is no reddit_accounts_active_48h_mean_lag21 in data frame
# There is no forks_mean_lag21 in data frame
# There is no stars_mean_lag21 in data frame
# There is no subscribers_mean_lag21 in data frame
# There is no total_issues_mean_lag21 in data frame
# There is no pull_requests_merged_mean_lag21 in data frame
# There is no commit_count_4_weeks_mean_lag21 in data frame
# There is no dogecoin_mean_lag21 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-11263.707, Time=6.86 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-8918.385, Time=1.76 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-12085.837, Time=5.98 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-8890.071, Time=2.13 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-8598.487, Time=8.45 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-11518.309, Time=11.18 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-12030.711, Time=12.41 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-4461.356, Time=6.81 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-11526.203, Time=7.62 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 63.207 seconds
# MAPE for 21 day lag prediction is 79.37291252181146
# There is no High_mean_lag30 in data frame
# There is no Low_mean_lag30 in data frame
# There is no Volume_mean_lag30 in data frame
# There is no twitter_followers_mean_lag30 in data frame
# There is no reddit_average_comments_48h_mean_lag30 in data frame
# There is no reddit_subscribers_mean_lag30 in data frame
# There is no reddit_accounts_active_48h_mean_lag30 in data frame
# There is no forks_mean_lag30 in data frame
# There is no stars_mean_lag30 in data frame
# There is no subscribers_mean_lag30 in data frame
# There is no total_issues_mean_lag30 in data frame
# There is no pull_requests_merged_mean_lag30 in data frame
# There is no commit_count_4_weeks_mean_lag30 in data frame
# There is no dogecoin_monthly_mean_lag30 in data frame
# There is no dogecoin_mean_lag30 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-12106.532, Time=23.85 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-8699.578, Time=1.54 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-10815.882, Time=3.69 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-8667.110, Time=1.94 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-8393.089, Time=6.10 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-10872.978, Time=5.87 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-4925.695, Time=6.17 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-12149.485, Time=12.88 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-10863.252, Time=6.40 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-4817.506, Time=8.38 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-10872.523, Time=8.22 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-10872.842, Time=7.03 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=-10859.164, Time=7.09 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=-10871.398, Time=8.49 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-12163.904, Time=13.13 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-11761.346, Time=22.46 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-12074.483, Time=26.57 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=-4821.006, Time=3.36 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-12095.430, Time=28.34 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=-4928.492, Time=2.13 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=-12097.428, Time=28.65 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=-12077.834, Time=29.82 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=-12097.226, Time=25.27 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0]
# Total fit time: 287.404 seconds
# MAPE for 30 day lag prediction is 78.67751427531496
# There is no High_mean_lag60 in data frame
# There is no Low_mean_lag60 in data frame
# There is no Volume_mean_lag60 in data frame
# There is no twitter_followers_mean_lag60 in data frame
# There is no reddit_average_comments_48h_mean_lag60 in data frame
# There is no reddit_subscribers_mean_lag60 in data frame
# There is no reddit_accounts_active_48h_mean_lag60 in data frame
# There is no forks_mean_lag60 in data frame
# There is no stars_mean_lag60 in data frame
# There is no subscribers_mean_lag60 in data frame
# There is no total_issues_mean_lag60 in data frame
# There is no closed_issues_mean_lag60 in data frame
# There is no pull_requests_merged_mean_lag60 in data frame
# There is no commit_count_4_weeks_mean_lag60 in data frame
# There is no dogecoin_monthly_mean_lag60 in data frame
# There is no dogecoin_mean_lag60 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-12553.570, Time=10.19 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-12454.676, Time=1.46 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-12456.373, Time=2.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-12455.386, Time=2.28 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-12455.790, Time=2.82 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-12501.953, Time=2.20 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-12452.151, Time=7.08 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-12546.574, Time=3.79 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-12586.369, Time=4.23 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-12496.325, Time=4.59 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-12580.741, Time=8.15 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-12574.474, Time=4.46 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-12513.924, Time=3.92 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-12573.250, Time=7.26 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-12587.585, Time=3.74 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-12497.254, Time=3.16 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=-12555.317, Time=7.89 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-12581.814, Time=6.61 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=-12575.925, Time=4.00 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-12502.726, Time=4.02 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-12515.128, Time=3.32 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-12550.284, Time=2.07 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=-12573.423, Time=7.85 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 107.226 seconds
# MAPE for 60 day lag prediction is 72.38126085861526

# %%
#Predikcija za skup 90:10
for window in windows:
    df_doge = pd.read_csv(f'../doge_{window}d_lag.csv', parse_dates=['Date'], date_parser=dateparse)
    df_doge.set_index(["Date"], drop=False, inplace=True)
    train, test = train_test_split_continual(df_doge, 0.1)
    predict_with_windows([window], train, test, lag_features)
# Out:
# There is no High_mean_lag3 in data frame
# There is no Low_mean_lag3 in data frame
# There is no Volume_mean_lag3 in data frame
# There is no twitter_followers_mean_lag3 in data frame
# There is no reddit_average_comments_48h_mean_lag3 in data frame
# There is no reddit_subscribers_mean_lag3 in data frame
# There is no reddit_accounts_active_48h_mean_lag3 in data frame
# There is no forks_mean_lag3 in data frame
# There is no stars_mean_lag3 in data frame
# There is no subscribers_mean_lag3 in data frame
# There is no total_issues_mean_lag3 in data frame
# There is no pull_requests_merged_mean_lag3 in data frame
# There is no commit_count_4_weeks_mean_lag3 in data frame
# There is no dogecoin_mean_lag3 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-7598.123, Time=51.84 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-6381.134, Time=1.94 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-7532.590, Time=4.92 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-7195.275, Time=1.95 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-6276.703, Time=7.56 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-7520.484, Time=49.67 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-5654.887, Time=2.90 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-7666.366, Time=62.53 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-7518.019, Time=3.67 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-7954.056, Time=10.04 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=-7814.495, Time=4.05 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=-7890.264, Time=7.09 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=-7900.113, Time=4.93 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-7261.604, Time=4.68 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=-7770.472, Time=5.07 sec
#  ARIMA(5,0,3)(0,0,0)[0] intercept   : AIC=-7892.496, Time=5.69 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=-7955.989, Time=9.36 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=-7668.281, Time=8.16 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=-7816.273, Time=8.74 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=-7892.179, Time=11.53 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=-7902.066, Time=62.53 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=-7519.968, Time=7.73 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=-7263.328, Time=3.98 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=-7772.270, Time=10.04 sec
#  ARIMA(5,0,3)(0,0,0)[0]             : AIC=-7894.435, Time=12.13 sec
#
# Best model:  ARIMA(4,0,2)(0,0,0)[0]
# Total fit time: 362.802 seconds
# MAPE for 3 day lag prediction is 7.127833892122635
# There is no High_mean_lag7 in data frame
# There is no Low_mean_lag7 in data frame
# There is no Volume_mean_lag7 in data frame
# There is no twitter_followers_mean_lag7 in data frame
# There is no reddit_average_comments_48h_mean_lag7 in data frame
# There is no reddit_subscribers_mean_lag7 in data frame
# There is no reddit_accounts_active_48h_mean_lag7 in data frame
# There is no forks_mean_lag7 in data frame
# There is no stars_mean_lag7 in data frame
# There is no subscribers_mean_lag7 in data frame
# There is no total_issues_mean_lag7 in data frame
# There is no pull_requests_merged_mean_lag7 in data frame
# There is no commit_count_4_weeks_mean_lag7 in data frame
# There is no dogecoin_mean_lag7 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-7333.913, Time=3.77 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-5527.752, Time=1.93 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-7294.665, Time=6.10 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-6279.686, Time=2.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-5472.717, Time=8.07 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-7387.079, Time=10.56 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-5349.795, Time=7.67 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-7325.262, Time=6.02 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-7491.521, Time=15.19 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=7.47 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-7474.539, Time=18.69 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=-7478.231, Time=15.69 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=-6999.575, Time=11.36 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=-7463.027, Time=10.12 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=-7492.621, Time=31.55 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=inf, Time=6.90 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=-7388.328, Time=10.01 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=-7476.307, Time=17.03 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=-7484.686, Time=16.38 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=-5223.341, Time=7.85 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=-6170.622, Time=11.78 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=-7335.887, Time=3.94 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=-7465.063, Time=9.31 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 239.793 seconds
# MAPE for 7 day lag prediction is 8.750065113773742
# There is no High_mean_lag14 in data frame
# There is no Low_mean_lag14 in data frame
# There is no Volume_mean_lag14 in data frame
# There is no twitter_followers_mean_lag14 in data frame
# There is no reddit_average_comments_48h_mean_lag14 in data frame
# There is no reddit_subscribers_mean_lag14 in data frame
# There is no reddit_accounts_active_48h_mean_lag14 in data frame
# There is no forks_mean_lag14 in data frame
# There is no stars_mean_lag14 in data frame
# There is no subscribers_mean_lag14 in data frame
# There is no total_issues_mean_lag14 in data frame
# There is no pull_requests_merged_mean_lag14 in data frame
# There is no commit_count_4_weeks_mean_lag14 in data frame
# There is no dogecoin_mean_lag14 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-7599.273, Time=7.57 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-4895.261, Time=1.92 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-8000.287, Time=9.76 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-5709.530, Time=2.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-4856.466, Time=7.54 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-7590.405, Time=5.76 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-7590.513, Time=8.72 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-4876.934, Time=44.90 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=-7901.542, Time=6.37 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 94.909 seconds
# MAPE for 14 day lag prediction is 56.82886980326158
# There is no High_mean_lag21 in data frame
# There is no Low_mean_lag21 in data frame
# There is no Volume_mean_lag21 in data frame
# There is no twitter_followers_mean_lag21 in data frame
# There is no reddit_average_comments_48h_mean_lag21 in data frame
# There is no reddit_subscribers_mean_lag21 in data frame
# There is no reddit_accounts_active_48h_mean_lag21 in data frame
# There is no forks_mean_lag21 in data frame
# There is no stars_mean_lag21 in data frame
# There is no subscribers_mean_lag21 in data frame
# There is no total_issues_mean_lag21 in data frame
# There is no pull_requests_merged_mean_lag21 in data frame
# There is no commit_count_4_weeks_mean_lag21 in data frame
# There is no dogecoin_mean_lag21 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-7755.733, Time=8.93 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-4478.499, Time=1.93 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-7746.019, Time=6.69 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-5252.619, Time=2.42 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-4452.249, Time=6.68 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-7758.988, Time=10.98 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-5358.199, Time=8.83 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-7957.033, Time=7.26 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=2642.042, Time=34.52 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-7732.144, Time=5.89 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=-7732.803, Time=6.97 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0] intercept
# Total fit time: 101.128 seconds
# MAPE for 21 day lag prediction is 100.18335554364626
# There is no High_mean_lag30 in data frame
# There is no Low_mean_lag30 in data frame
# There is no Volume_mean_lag30 in data frame
# There is no twitter_followers_mean_lag30 in data frame
# There is no reddit_average_comments_48h_mean_lag30 in data frame
# There is no reddit_subscribers_mean_lag30 in data frame
# There is no reddit_accounts_active_48h_mean_lag30 in data frame
# There is no forks_mean_lag30 in data frame
# There is no stars_mean_lag30 in data frame
# There is no subscribers_mean_lag30 in data frame
# There is no total_issues_mean_lag30 in data frame
# There is no pull_requests_merged_mean_lag30 in data frame
# There is no commit_count_4_weeks_mean_lag30 in data frame
# There is no dogecoin_monthly_mean_lag30 in data frame
# There is no dogecoin_mean_lag30 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-4110.094, Time=30.64 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-4114.839, Time=1.73 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-7759.480, Time=5.17 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-5031.691, Time=2.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-4063.291, Time=4.62 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-7780.867, Time=4.77 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-7764.542, Time=5.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-7764.034, Time=7.30 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-7780.108, Time=8.15 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-7762.764, Time=6.62 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=-7769.884, Time=5.66 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 81.833 seconds
# MAPE for 30 day lag prediction is 33.50137387733538
# There is no High_mean_lag60 in data frame
# There is no Low_mean_lag60 in data frame
# There is no Volume_mean_lag60 in data frame
# There is no twitter_followers_mean_lag60 in data frame
# There is no reddit_average_comments_48h_mean_lag60 in data frame
# There is no reddit_subscribers_mean_lag60 in data frame
# There is no reddit_accounts_active_48h_mean_lag60 in data frame
# There is no forks_mean_lag60 in data frame
# There is no stars_mean_lag60 in data frame
# There is no subscribers_mean_lag60 in data frame
# There is no total_issues_mean_lag60 in data frame
# There is no closed_issues_mean_lag60 in data frame
# There is no pull_requests_merged_mean_lag60 in data frame
# There is no commit_count_4_weeks_mean_lag60 in data frame
# There is no dogecoin_monthly_mean_lag60 in data frame
# There is no dogecoin_mean_lag60 in data frame
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-8081.035, Time=7.55 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=-3853.238, Time=2.80 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=-7972.364, Time=6.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=-5310.151, Time=5.82 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=-3853.511, Time=2.97 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-8083.454, Time=8.31 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=-6330.615, Time=17.12 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-8028.933, Time=9.68 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-8141.325, Time=12.87 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=-6178.087, Time=4.50 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-8147.024, Time=9.88 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-8123.418, Time=10.05 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=-8172.881, Time=11.63 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=-8147.677, Time=10.52 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=-8188.429, Time=12.21 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=-8106.326, Time=12.80 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=-8212.407, Time=12.58 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=-8215.796, Time=12.04 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=-8224.747, Time=11.11 sec
#  ARIMA(0,0,5)(0,0,0)[0] intercept   : AIC=-7446.048, Time=11.46 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=-6945.388, Time=8.65 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=-8217.912, Time=10.19 sec
#
# Best model:  ARIMA(1,0,5)(0,0,0)[0] intercept
# Total fit time: 210.845 seconds
# MAPE for 60 day lag prediction is 18.33104912801156
