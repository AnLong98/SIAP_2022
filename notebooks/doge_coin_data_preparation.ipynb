# %%
import pandas as pd

df = pd.read_csv('../doge_data_4_2_2022.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1549 non-null   object
#  1   Open                         1549 non-null   float64
#  2   High                         1549 non-null   float64
#  3   Low                          1549 non-null   float64
#  4   Close                        1549 non-null   float64
#  5   Adj Close                    1549 non-null   float64
#  6   Volume                       1549 non-null   int64
#  7   facebook_likes               0 non-null      float64
#  8   twitter_followers            1510 non-null   float64
#  9   reddit_average_posts_48h     1549 non-null   float64
#  10  reddit_average_comments_48h  1549 non-null   float64
#  11  reddit_subscribers           1539 non-null   float64
#  12  reddit_accounts_active_48h   1539 non-null   float64
#  13  forks                        1525 non-null   float64
#  14  stars                        1525 non-null   float64
#  15  subscribers                  1525 non-null   float64
#  16  total_issues                 1525 non-null   float64
#  17  closed_issues                1525 non-null   float64
#  18  pull_requests_merged         1533 non-null   float64
#  19  pull_request_contributors    1533 non-null   float64
#  20  commit_count_4_weeks         1527 non-null   float64
#  21  dogecoin_unscaled            1549 non-null   int64
#  22  dogecoin_monthly             1549 non-null   float64
#  23  isPartial                    221 non-null    object
#  24  scale                        1549 non-null   float64
#  25  dogecoin                     1549 non-null   float64
# dtypes: float64(22), int64(2), object(2)
# memory usage: 314.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1549 non-null   object
#  1   Open                         1549 non-null   float64
#  2   High                         1549 non-null   float64
#  3   Low                          1549 non-null   float64
#  4   Close                        1549 non-null   float64
#  5   Adj Close                    1549 non-null   float64
#  6   Volume                       1549 non-null   int64
#  7   facebook_likes               0 non-null      float64
#  8   twitter_followers            1510 non-null   float64
#  9   reddit_average_posts_48h     1549 non-null   float64
#  10  reddit_average_comments_48h  1549 non-null   float64
#  11  reddit_subscribers           1539 non-null   float64
#  12  reddit_accounts_active_48h   1539 non-null   float64
#  13  forks                        1525 non-null   float64
#  14  stars                        1525 non-null   float64
#  15  subscribers                  1525 non-null   float64
#  16  total_issues                 1525 non-null   float64
#  17  closed_issues                1525 non-null   float64
#  18  pull_requests_merged         1533 non-null   float64
#  19  pull_request_contributors    1533 non-null   float64
#  20  commit_count_4_weeks         1527 non-null   float64
#  21  dogecoin_unscaled            1549 non-null   int64
#  22  dogecoin_monthly             1549 non-null   float64
#  23  isPartial                    221 non-null    object
#  24  scale                        1549 non-null   float64
#  25  dogecoin                     1549 non-null   float64
# dtypes: float64(22), int64(2), object(2)
# memory usage: 314.8+ KB

# %%
#Cela kolona facebook_likes je NULL uklanjam je
del df['facebook_likes']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1549 non-null   object
#  1   Open                         1549 non-null   float64
#  2   High                         1549 non-null   float64
#  3   Low                          1549 non-null   float64
#  4   Close                        1549 non-null   float64
#  5   Adj Close                    1549 non-null   float64
#  6   Volume                       1549 non-null   int64
#  7   twitter_followers            1510 non-null   float64
#  8   reddit_average_posts_48h     1549 non-null   float64
#  9   reddit_average_comments_48h  1549 non-null   float64
#  10  reddit_subscribers           1539 non-null   float64
#  11  reddit_accounts_active_48h   1539 non-null   float64
#  12  forks                        1525 non-null   float64
#  13  stars                        1525 non-null   float64
#  14  subscribers                  1525 non-null   float64
#  15  total_issues                 1525 non-null   float64
#  16  closed_issues                1525 non-null   float64
#  17  pull_requests_merged         1533 non-null   float64
#  18  pull_request_contributors    1533 non-null   float64
#  19  commit_count_4_weeks         1527 non-null   float64
#  20  dogecoin_unscaled            1549 non-null   int64
#  21  dogecoin_monthly             1549 non-null   float64
#  22  isPartial                    221 non-null    object
#  23  scale                        1549 non-null   float64
#  24  dogecoin                     1549 non-null   float64
# dtypes: float64(21), int64(2), object(2)
# memory usage: 302.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1549 non-null   object
#  1   Open                         1549 non-null   float64
#  2   High                         1549 non-null   float64
#  3   Low                          1549 non-null   float64
#  4   Close                        1549 non-null   float64
#  5   Adj Close                    1549 non-null   float64
#  6   Volume                       1549 non-null   int64
#  7   twitter_followers            1510 non-null   float64
#  8   reddit_average_posts_48h     1549 non-null   float64
#  9   reddit_average_comments_48h  1549 non-null   float64
#  10  reddit_subscribers           1539 non-null   float64
#  11  reddit_accounts_active_48h   1539 non-null   float64
#  12  forks                        1525 non-null   float64
#  13  stars                        1525 non-null   float64
#  14  subscribers                  1525 non-null   float64
#  15  total_issues                 1525 non-null   float64
#  16  closed_issues                1525 non-null   float64
#  17  pull_requests_merged         1533 non-null   float64
#  18  pull_request_contributors    1533 non-null   float64
#  19  commit_count_4_weeks         1527 non-null   float64
#  20  dogecoin_unscaled            1549 non-null   int64
#  21  dogecoin_monthly             1549 non-null   float64
#  22  isPartial                    221 non-null    object
#  23  scale                        1549 non-null   float64
#  24  dogecoin                     1549 non-null   float64
# dtypes: float64(21), int64(2), object(2)
# memory usage: 302.7+ KB

# %%
#Is partial ima 221/1549 i nju izbacujem
del df['isPartial']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1549 non-null   object
#  1   Open                         1549 non-null   float64
#  2   High                         1549 non-null   float64
#  3   Low                          1549 non-null   float64
#  4   Close                        1549 non-null   float64
#  5   Adj Close                    1549 non-null   float64
#  6   Volume                       1549 non-null   int64
#  7   twitter_followers            1510 non-null   float64
#  8   reddit_average_posts_48h     1549 non-null   float64
#  9   reddit_average_comments_48h  1549 non-null   float64
#  10  reddit_subscribers           1539 non-null   float64
#  11  reddit_accounts_active_48h   1539 non-null   float64
#  12  forks                        1525 non-null   float64
#  13  stars                        1525 non-null   float64
#  14  subscribers                  1525 non-null   float64
#  15  total_issues                 1525 non-null   float64
#  16  closed_issues                1525 non-null   float64
#  17  pull_requests_merged         1533 non-null   float64
#  18  pull_request_contributors    1533 non-null   float64
#  19  commit_count_4_weeks         1527 non-null   float64
#  20  dogecoin_unscaled            1549 non-null   int64
#  21  dogecoin_monthly             1549 non-null   float64
#  22  scale                        1549 non-null   float64
#  23  dogecoin                     1549 non-null   float64
# dtypes: float64(21), int64(2), object(1)
# memory usage: 290.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1549 entries, 0 to 1548
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1549 non-null   object
#  1   Open                         1549 non-null   float64
#  2   High                         1549 non-null   float64
#  3   Low                          1549 non-null   float64
#  4   Close                        1549 non-null   float64
#  5   Adj Close                    1549 non-null   float64
#  6   Volume                       1549 non-null   int64
#  7   twitter_followers            1510 non-null   float64
#  8   reddit_average_posts_48h     1549 non-null   float64
#  9   reddit_average_comments_48h  1549 non-null   float64
#  10  reddit_subscribers           1539 non-null   float64
#  11  reddit_accounts_active_48h   1539 non-null   float64
#  12  forks                        1525 non-null   float64
#  13  stars                        1525 non-null   float64
#  14  subscribers                  1525 non-null   float64
#  15  total_issues                 1525 non-null   float64
#  16  closed_issues                1525 non-null   float64
#  17  pull_requests_merged         1533 non-null   float64
#  18  pull_request_contributors    1533 non-null   float64
#  19  commit_count_4_weeks         1527 non-null   float64
#  20  dogecoin_unscaled            1549 non-null   int64
#  21  dogecoin_monthly             1549 non-null   float64
#  22  scale                        1549 non-null   float64
#  23  dogecoin                     1549 non-null   float64
# dtypes: float64(21), int64(2), object(1)
# memory usage: 290.6+ KB

# %%
#Da vidim koliko tacno fali u kojoj koloni
df.isna().sum(axis = 0)
# Out:
# Date                            0
# Open                            0
# High                            0
# Low                             0
# Close                           0
# Adj Close                       0
# Volume                          0
# twitter_followers              39
# reddit_average_posts_48h        0
# reddit_average_comments_48h     0
# reddit_subscribers             10
# reddit_accounts_active_48h     10
# forks                          24
# stars                          24
# subscribers                    24
# total_issues                   24
# closed_issues                  24
# pull_requests_merged           16
# pull_request_contributors      16
# commit_count_4_weeks           22
# dogecoin_unscaled               0
# dogecoin_monthly                0
# scale                           0
# dogecoin                        0
# dtype: int64
# Date                            0
# Open                            0
# High                            0
# Low                             0
# Close                           0
# Adj Close                       0
# Volume                          0
# twitter_followers              39
# reddit_average_posts_48h        0
# reddit_average_comments_48h     0
# reddit_subscribers             10
# reddit_accounts_active_48h     10
# forks                          24
# stars                          24
# subscribers                    24
# total_issues                   24
# closed_issues                  24
# pull_requests_merged           16
# pull_request_contributors      16
# commit_count_4_weeks           22
# dogecoin_unscaled               0
# dogecoin_monthly                0
# scale                           0
# dogecoin                        0
# dtype: int64

# %%
df.shape
# Out:
# (1549, 24)
# (1549, 24)

# %%
#Da vidim koliko posto twiter podataka fali
39/1549
# Out:
# 0.025177533892834086
# 0.025177533892834086

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume  \
# 0  09/11/2017  0.001207  0.001415  0.001181  0.001415   0.001415  6259550
# 1  10/11/2017  0.001421  0.001431  0.001125  0.001163   0.001163  4246520
# 2  11/11/2017  0.001146  0.001257  0.001141  0.001201   0.001201  2231080
# 3  12/11/2017  0.001189  0.001210  0.001002  0.001038   0.001038  3288960
# 4  13/11/2017  0.001046  0.001212  0.001019  0.001211   0.001211  2481270
#
#    twitter_followers  reddit_average_posts_48h  reddit_average_comments_48h  \
# 0           165257.0                     0.633                        9.490
# 1           165308.0                     0.833                       11.958
# 2           165363.0                     0.980                       13.224
# 3           165402.0                     1.102                       14.469
# 4                NaN                     1.277                       15.383
#
#    ...  subscribers  total_issues  closed_issues  pull_requests_merged  \
# 0  ...        225.0         395.0          336.0                 732.0
# 1  ...          NaN           NaN            NaN                 732.0
# 2  ...          NaN           NaN            NaN                 732.0
# 3  ...          NaN           NaN            NaN                 732.0
# 4  ...          NaN           NaN            NaN                 732.0
#
#    pull_request_contributors  commit_count_4_weeks  dogecoin_unscaled  \
# 0                       67.0                   0.0                 57
# 1                       67.0                   NaN                 24
# 2                       67.0                   NaN                 23
# 3                       67.0                   NaN                 23
# 4                       67.0                   NaN                 41
#
#    dogecoin_monthly  scale  dogecoin
# 0               1.0   0.01      0.57
# 1               1.0   0.01      0.24
# 2               1.0   0.01      0.23
# 3               1.0   0.01      0.23
# 4               1.0   0.01      0.41
#
# [5 rows x 24 columns]
#          Date      Open      High       Low     Close  Adj Close   Volume  \
# 0  09/11/2017  0.001207  0.001415  0.001181  0.001415   0.001415  6259550
# 1  10/11/2017  0.001421  0.001431  0.001125  0.001163   0.001163  4246520
# 2  11/11/2017  0.001146  0.001257  0.001141  0.001201   0.001201  2231080
# 3  12/11/2017  0.001189  0.001210  0.001002  0.001038   0.001038  3288960
# 4  13/11/2017  0.001046  0.001212  0.001019  0.001211   0.001211  2481270
#
#    twitter_followers  reddit_average_posts_48h  reddit_average_comments_48h  \
# 0           165257.0                     0.633                        9.490
# 1           165308.0                     0.833                       11.958
# 2           165363.0                     0.980                       13.224
# 3           165402.0                     1.102                       14.469
# 4                NaN                     1.277                       15.383
#
#    ...  subscribers  total_issues  closed_issues  pull_requests_merged  \
# 0  ...        225.0         395.0          336.0                 732.0
# 1  ...          NaN           NaN            NaN                 732.0
# 2  ...          NaN           NaN            NaN                 732.0
# 3  ...          NaN           NaN            NaN                 732.0
# 4  ...          NaN           NaN            NaN                 732.0
#
#    pull_request_contributors  commit_count_4_weeks  dogecoin_unscaled  \
# 0                       67.0                   0.0                 57
# 1                       67.0                   NaN                 24
# 2                       67.0                   NaN                 23
# 3                       67.0                   NaN                 23
# 4                       67.0                   NaN                 41
#
#    dogecoin_monthly  scale  dogecoin
# 0               1.0   0.01      0.57
# 1               1.0   0.01      0.24
# 2               1.0   0.01      0.23
# 3               1.0   0.01      0.23
# 4               1.0   0.01      0.41
#
# [5 rows x 24 columns]

# %%
# !{sys.executable} -m pip install scipy
import scipy
#Interpolacijom popunjavam nedostajuce vrednosti zbog pretpostavke da broj twitter pratilaca raste po nekoj zakonitosti
df['twitter_followers'] = df['twitter_followers'].interpolate(method='slinear').interpolate(method='linear')
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume  \
# 0  09/11/2017  0.001207  0.001415  0.001181  0.001415   0.001415  6259550
# 1  10/11/2017  0.001421  0.001431  0.001125  0.001163   0.001163  4246520
# 2  11/11/2017  0.001146  0.001257  0.001141  0.001201   0.001201  2231080
# 3  12/11/2017  0.001189  0.001210  0.001002  0.001038   0.001038  3288960
# 4  13/11/2017  0.001046  0.001212  0.001019  0.001211   0.001211  2481270
#
#    twitter_followers  reddit_average_posts_48h  reddit_average_comments_48h  \
# 0      165257.000000                     0.633                        9.490
# 1      165308.000000                     0.833                       11.958
# 2      165363.000000                     0.980                       13.224
# 3      165402.000000                     1.102                       14.469
# 4      165452.666667                     1.277                       15.383
#
#    ...  subscribers  total_issues  closed_issues  pull_requests_merged  \
# 0  ...        225.0         395.0          336.0                 732.0
# 1  ...          NaN           NaN            NaN                 732.0
# 2  ...          NaN           NaN            NaN                 732.0
# 3  ...          NaN           NaN            NaN                 732.0
# 4  ...          NaN           NaN            NaN                 732.0
#
#    pull_request_contributors  commit_count_4_weeks  dogecoin_unscaled  \
# 0                       67.0                   0.0                 57
# 1                       67.0                   NaN                 24
# 2                       67.0                   NaN                 23
# 3                       67.0                   NaN                 23
# 4                       67.0                   NaN                 41
#
#    dogecoin_monthly  scale  dogecoin
# 0               1.0   0.01      0.57
# 1               1.0   0.01      0.24
# 2               1.0   0.01      0.23
# 3               1.0   0.01      0.23
# 4               1.0   0.01      0.41
#
# [5 rows x 24 columns]
#          Date      Open      High       Low     Close  Adj Close   Volume  \
# 0  09/11/2017  0.001207  0.001415  0.001181  0.001415   0.001415  6259550
# 1  10/11/2017  0.001421  0.001431  0.001125  0.001163   0.001163  4246520
# 2  11/11/2017  0.001146  0.001257  0.001141  0.001201   0.001201  2231080
# 3  12/11/2017  0.001189  0.001210  0.001002  0.001038   0.001038  3288960
# 4  13/11/2017  0.001046  0.001212  0.001019  0.001211   0.001211  2481270
#
#    twitter_followers  reddit_average_posts_48h  reddit_average_comments_48h  \
# 0      165257.000000                     0.633                        9.490
# 1      165308.000000                     0.833                       11.958
# 2      165363.000000                     0.980                       13.224
# 3      165402.000000                     1.102                       14.469
# 4      165452.666667                     1.277                       15.383
#
#    ...  subscribers  total_issues  closed_issues  pull_requests_merged  \
# 0  ...        225.0         395.0          336.0                 732.0
# 1  ...          NaN           NaN            NaN                 732.0
# 2  ...          NaN           NaN            NaN                 732.0
# 3  ...          NaN           NaN            NaN                 732.0
# 4  ...          NaN           NaN            NaN                 732.0
#
#    pull_request_contributors  commit_count_4_weeks  dogecoin_unscaled  \
# 0                       67.0                   0.0                 57
# 1                       67.0                   NaN                 24
# 2                       67.0                   NaN                 23
# 3                       67.0                   NaN                 23
# 4                       67.0                   NaN                 41
#
#    dogecoin_monthly  scale  dogecoin
# 0               1.0   0.01      0.57
# 1               1.0   0.01      0.24
# 2               1.0   0.01      0.23
# 3               1.0   0.01      0.23
# 4               1.0   0.01      0.41
#
# [5 rows x 24 columns]

# %%
df.isna().sum(axis = 0)
# Out:
# Date                            0
# Open                            0
# High                            0
# Low                             0
# Close                           0
# Adj Close                       0
# Volume                          0
# twitter_followers               0
# reddit_average_posts_48h        0
# reddit_average_comments_48h     0
# reddit_subscribers             10
# reddit_accounts_active_48h     10
# forks                          24
# stars                          24
# subscribers                    24
# total_issues                   24
# closed_issues                  24
# pull_requests_merged           16
# pull_request_contributors      16
# commit_count_4_weeks           22
# dogecoin_unscaled               0
# dogecoin_monthly                0
# scale                           0
# dogecoin                        0
# dtype: int64
# Date                            0
# Open                            0
# High                            0
# Low                             0
# Close                           0
# Adj Close                       0
# Volume                          0
# twitter_followers               0
# reddit_average_posts_48h        0
# reddit_average_comments_48h     0
# reddit_subscribers             10
# reddit_accounts_active_48h     10
# forks                          24
# stars                          24
# subscribers                    24
# total_issues                   24
# closed_issues                  24
# pull_requests_merged           16
# pull_request_contributors      16
# commit_count_4_weeks           22
# dogecoin_unscaled               0
# dogecoin_monthly                0
# scale                           0
# dogecoin                        0
# dtype: int64

# %%
to_fill = ['reddit_subscribers', 'reddit_accounts_active_48h', 'forks', 'stars', 'subscribers', 'total_issues',
           'closed_issues', 'pull_requests_merged', 'pull_request_contributors', 'commit_count_4_weeks']
for col in to_fill:
    df[col] = df[col].interpolate(method='slinear').interpolate(method='linear')

# %%
df.isna().sum(axis = 0)
# Out:
# Date                           0
# Open                           0
# High                           0
# Low                            0
# Close                          0
# Adj Close                      0
# Volume                         0
# twitter_followers              0
# reddit_average_posts_48h       0
# reddit_average_comments_48h    0
# reddit_subscribers             0
# reddit_accounts_active_48h     0
# forks                          0
# stars                          0
# subscribers                    0
# total_issues                   0
# closed_issues                  0
# pull_requests_merged           0
# pull_request_contributors      0
# commit_count_4_weeks           0
# dogecoin_unscaled              0
# dogecoin_monthly               0
# scale                          0
# dogecoin                       0
# dtype: int64
# Date                           0
# Open                           0
# High                           0
# Low                            0
# Close                          0
# Adj Close                      0
# Volume                         0
# twitter_followers              0
# reddit_average_posts_48h       0
# reddit_average_comments_48h    0
# reddit_subscribers             0
# reddit_accounts_active_48h     0
# forks                          0
# stars                          0
# subscribers                    0
# total_issues                   0
# closed_issues                  0
# pull_requests_merged           0
# pull_request_contributors      0
# commit_count_4_weeks           0
# dogecoin_unscaled              0
# dogecoin_monthly               0
# scale                          0
# dogecoin                       0
# dtype: int64

# %%
#Da vidim ima li duplikata
df.nunique()
# Out:
# Date                           1549
# Open                           1323
# High                           1327
# Low                            1316
# Close                          1332
# Adj Close                      1332
# Volume                         1549
# twitter_followers              1468
# reddit_average_posts_48h        510
# reddit_average_comments_48h    1317
# reddit_subscribers             1548
# reddit_accounts_active_48h     1521
# forks                           549
# stars                           808
# subscribers                     195
# total_issues                    276
# closed_issues                   182
# pull_requests_merged            178
# pull_request_contributors        56
# commit_count_4_weeks             60
# dogecoin_unscaled               101
# dogecoin_monthly                 28
# scale                            28
# dogecoin                        353
# dtype: int64
# Date                           1549
# Open                           1323
# High                           1327
# Low                            1316
# Close                          1332
# Adj Close                      1332
# Volume                         1549
# twitter_followers              1468
# reddit_average_posts_48h        510
# reddit_average_comments_48h    1317
# reddit_subscribers             1548
# reddit_accounts_active_48h     1521
# forks                           549
# stars                           808
# subscribers                     195
# total_issues                    276
# closed_issues                   182
# pull_requests_merged            178
# pull_request_contributors        56
# commit_count_4_weeks             60
# dogecoin_unscaled               101
# dogecoin_monthly                 28
# scale                            28
# dogecoin                        353
# dtype: int64

# %%
# !{sys.executable} -m pip install  matplotlib
# !{sys.executable} -m pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax = sns.boxplot(data=df, orient="h", palette="Set2")

# %%
#plot = sns.pairplot(df)
#fig = plot.fig
#fig.savefig("../doge_pair_plot.png")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['Volume'], df['Close'])
ax.set_xlabel('Volume')
ax.set_ylabel('Close')
plt.show()

# %%
#Skidam outlier za volume
df = df.drop(df[df.Volume > 6e10].index)
df[df['Volume']>6e10]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, twitter_followers, reddit_average_posts_48h, reddit_average_comments_48h, reddit_subscribers, reddit_accounts_active_48h, forks, stars, subscribers, total_issues, closed_issues, pull_requests_merged, pull_request_contributors, commit_count_4_weeks, dogecoin_unscaled, dogecoin_monthly, scale, dogecoin]
# Index: []
#
# [0 rows x 24 columns]
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, twitter_followers, reddit_average_posts_48h, reddit_average_comments_48h, reddit_subscribers, reddit_accounts_active_48h, forks, stars, subscribers, total_issues, closed_issues, pull_requests_merged, pull_request_contributors, commit_count_4_weeks, dogecoin_unscaled, dogecoin_monthly, scale, dogecoin]
# Index: []
#
# [0 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['dogecoin'], df['Close'])
ax.set_xlabel('dogecoin')
ax.set_ylabel('Close')
plt.show()

# %%
#Skidam outlier za dogecoin
df = df.drop(df[df.dogecoin > 60].index)
df[df['dogecoin']>60]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, twitter_followers, reddit_average_posts_48h, reddit_average_comments_48h, reddit_subscribers, reddit_accounts_active_48h, forks, stars, subscribers, total_issues, closed_issues, pull_requests_merged, pull_request_contributors, commit_count_4_weeks, dogecoin_unscaled, dogecoin_monthly, scale, dogecoin]
# Index: []
#
# [0 rows x 24 columns]
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume, twitter_followers, reddit_average_posts_48h, reddit_average_comments_48h, reddit_subscribers, reddit_accounts_active_48h, forks, stars, subscribers, total_issues, closed_issues, pull_requests_merged, pull_request_contributors, commit_count_4_weeks, dogecoin_unscaled, dogecoin_monthly, scale, dogecoin]
# Index: []
#
# [0 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['total_issues'], df['Open'])
ax.set_xlabel('Issues')
ax.set_ylabel('Open')
plt.show()

# %%
#Proveravam koliko tacaka pada na 0,0
df[df.total_issues == 0]
#Da li ovo skinuti?
# Out:
#            Date      Open      High       Low     Close  Adj Close     Volume  \
# 510  03/04/2019  0.002777  0.003656  0.002771  0.003164   0.003164   89863287
# 511  04/04/2019  0.003158  0.004096  0.003134  0.003697   0.003697  164634741
# 512  05/04/2019  0.003679  0.003755  0.003409  0.003590   0.003590   63331136
# 513  06/04/2019  0.003594  0.003594  0.003415  0.003439   0.003439   46343810
# 514  07/04/2019  0.003440  0.003517  0.003256  0.003418   0.003418   50224984
# ..          ...       ...       ...       ...       ...        ...        ...
# 799  17/01/2020  0.002346  0.002516  0.002310  0.002490   0.002490  117752841
# 800  18/01/2020  0.002490  0.002538  0.002452  0.002507   0.002507  108133943
# 801  19/01/2020  0.002514  0.002570  0.002359  0.002405   0.002405  108085147
# 802  20/01/2020  0.002405  0.002423  0.002359  0.002374   0.002374   92022277
# 803  21/01/2020  0.002374  0.002403  0.002335  0.002376   0.002376   84321565
#
#      twitter_followers  reddit_average_posts_48h  reddit_average_comments_48h  \
# 510           132989.0                     3.696                       37.565
# 511           133656.0                     3.560                       42.240
# 512           133995.0                     3.458                       35.083
# 513           134114.0                     2.043                       24.739
# 514           134239.0                     1.696                       41.609
# ..                 ...                       ...                          ...
# 799           138693.0                     2.167                       21.917
# 800           138701.0                     1.750                       19.917
# 801           138715.0                     1.727                       16.182
# 802           138733.0                     1.545                       23.182
# 803           138752.0                     1.455                       20.727
#
#      ...  subscribers  total_issues  closed_issues  pull_requests_merged  \
# 510  ...        282.0           0.0            0.0                 800.0
# 511  ...        282.0           0.0            0.0                 800.0
# 512  ...        281.0           0.0            0.0                 800.0
# 513  ...        281.0           0.0            0.0                 800.0
# 514  ...        281.0           0.0            0.0                 800.0
# ..   ...          ...           ...            ...                   ...
# 799  ...        274.0           0.0            0.0                 808.0
# 800  ...        274.0           0.0            0.0                 808.0
# 801  ...        274.0           0.0            0.0                 808.0
# 802  ...        274.0           0.0            0.0                 808.0
# 803  ...        274.0           0.0            0.0                 808.0
#
#      pull_request_contributors  commit_count_4_weeks  dogecoin_unscaled  \
# 510                       70.0                   0.0                100
# 511                       70.0                   0.0                 63
# 512                       70.0                   0.0                 42
# 513                       70.0                   0.0                 31
# 514                       70.0                   0.0                 33
# ..                         ...                   ...                ...
# 799                       70.0                   0.0                 70
# 800                       70.0                   0.0                 59
# 801                       70.0                   0.0                 52
# 802                       70.0                   0.0                 48
# 803                       70.0                   0.0                 31
#
#      dogecoin_monthly  scale  dogecoin
# 510               1.0   0.01      1.00
# 511               1.0   0.01      0.63
# 512               1.0   0.01      0.42
# 513               1.0   0.01      0.31
# 514               0.0   0.00      0.00
# ..                ...    ...       ...
# 799               0.0   0.00      0.00
# 800               0.0   0.00      0.00
# 801               0.0   0.00      0.00
# 802               0.0   0.00      0.00
# 803               0.0   0.00      0.00
#
# [294 rows x 24 columns]
#            Date      Open      High       Low     Close  Adj Close     Volume  \
# 510  03/04/2019  0.002777  0.003656  0.002771  0.003164   0.003164   89863287
# 511  04/04/2019  0.003158  0.004096  0.003134  0.003697   0.003697  164634741
# 512  05/04/2019  0.003679  0.003755  0.003409  0.003590   0.003590   63331136
# 513  06/04/2019  0.003594  0.003594  0.003415  0.003439   0.003439   46343810
# 514  07/04/2019  0.003440  0.003517  0.003256  0.003418   0.003418   50224984
# ..          ...       ...       ...       ...       ...        ...        ...
# 799  17/01/2020  0.002346  0.002516  0.002310  0.002490   0.002490  117752841
# 800  18/01/2020  0.002490  0.002538  0.002452  0.002507   0.002507  108133943
# 801  19/01/2020  0.002514  0.002570  0.002359  0.002405   0.002405  108085147
# 802  20/01/2020  0.002405  0.002423  0.002359  0.002374   0.002374   92022277
# 803  21/01/2020  0.002374  0.002403  0.002335  0.002376   0.002376   84321565
#
#      twitter_followers  reddit_average_posts_48h  reddit_average_comments_48h  \
# 510           132989.0                     3.696                       37.565
# 511           133656.0                     3.560                       42.240
# 512           133995.0                     3.458                       35.083
# 513           134114.0                     2.043                       24.739
# 514           134239.0                     1.696                       41.609
# ..                 ...                       ...                          ...
# 799           138693.0                     2.167                       21.917
# 800           138701.0                     1.750                       19.917
# 801           138715.0                     1.727                       16.182
# 802           138733.0                     1.545                       23.182
# 803           138752.0                     1.455                       20.727
#
#      ...  subscribers  total_issues  closed_issues  pull_requests_merged  \
# 510  ...        282.0           0.0            0.0                 800.0
# 511  ...        282.0           0.0            0.0                 800.0
# 512  ...        281.0           0.0            0.0                 800.0
# 513  ...        281.0           0.0            0.0                 800.0
# 514  ...        281.0           0.0            0.0                 800.0
# ..   ...          ...           ...            ...                   ...
# 799  ...        274.0           0.0            0.0                 808.0
# 800  ...        274.0           0.0            0.0                 808.0
# 801  ...        274.0           0.0            0.0                 808.0
# 802  ...        274.0           0.0            0.0                 808.0
# 803  ...        274.0           0.0            0.0                 808.0
#
#      pull_request_contributors  commit_count_4_weeks  dogecoin_unscaled  \
# 510                       70.0                   0.0                100
# 511                       70.0                   0.0                 63
# 512                       70.0                   0.0                 42
# 513                       70.0                   0.0                 31
# 514                       70.0                   0.0                 33
# ..                         ...                   ...                ...
# 799                       70.0                   0.0                 70
# 800                       70.0                   0.0                 59
# 801                       70.0                   0.0                 52
# 802                       70.0                   0.0                 48
# 803                       70.0                   0.0                 31
#
#      dogecoin_monthly  scale  dogecoin
# 510               1.0   0.01      1.00
# 511               1.0   0.01      0.63
# 512               1.0   0.01      0.42
# 513               1.0   0.01      0.31
# 514               0.0   0.00      0.00
# ..                ...    ...       ...
# 799               0.0   0.00      0.00
# 800               0.0   0.00      0.00
# 801               0.0   0.00      0.00
# 802               0.0   0.00      0.00
# 803               0.0   0.00      0.00
#
# [294 rows x 24 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df.set_index('Date', inplace=True)
df.to_csv('../doge_v1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1546 entries, 2017-11-09 to 2022-02-04
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Open                         1546 non-null   float64
#  1   High                         1546 non-null   float64
#  2   Low                          1546 non-null   float64
#  3   Close                        1546 non-null   float64
#  4   Adj Close                    1546 non-null   float64
#  5   Volume                       1546 non-null   int64
#  6   twitter_followers            1546 non-null   float64
#  7   reddit_average_posts_48h     1546 non-null   float64
#  8   reddit_average_comments_48h  1546 non-null   float64
#  9   reddit_subscribers           1546 non-null   float64
#  10  reddit_accounts_active_48h   1546 non-null   float64
#  11  forks                        1546 non-null   float64
#  12  stars                        1546 non-null   float64
#  13  subscribers                  1546 non-null   float64
#  14  total_issues                 1546 non-null   float64
#  15  closed_issues                1546 non-null   float64
#  16  pull_requests_merged         1546 non-null   float64
#  17  pull_request_contributors    1546 non-null   float64
#  18  commit_count_4_weeks         1546 non-null   float64
#  19  dogecoin_unscaled            1546 non-null   int64
#  20  dogecoin_monthly             1546 non-null   float64
#  21  scale                        1546 non-null   float64
#  22  dogecoin                     1546 non-null   float64
# dtypes: float64(21), int64(2)
# memory usage: 289.9 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1546 entries, 2017-11-09 to 2022-02-04
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Open                         1546 non-null   float64
#  1   High                         1546 non-null   float64
#  2   Low                          1546 non-null   float64
#  3   Close                        1546 non-null   float64
#  4   Adj Close                    1546 non-null   float64
#  5   Volume                       1546 non-null   int64
#  6   twitter_followers            1546 non-null   float64
#  7   reddit_average_posts_48h     1546 non-null   float64
#  8   reddit_average_comments_48h  1546 non-null   float64
#  9   reddit_subscribers           1546 non-null   float64
#  10  reddit_accounts_active_48h   1546 non-null   float64
#  11  forks                        1546 non-null   float64
#  12  stars                        1546 non-null   float64
#  13  subscribers                  1546 non-null   float64
#  14  total_issues                 1546 non-null   float64
#  15  closed_issues                1546 non-null   float64
#  16  pull_requests_merged         1546 non-null   float64
#  17  pull_request_contributors    1546 non-null   float64
#  18  commit_count_4_weeks         1546 non-null   float64
#  19  dogecoin_unscaled            1546 non-null   int64
#  20  dogecoin_monthly             1546 non-null   float64
#  21  scale                        1546 non-null   float64
#  22  dogecoin                     1546 non-null   float64
# dtypes: float64(21), int64(2)
# memory usage: 289.9 KB
